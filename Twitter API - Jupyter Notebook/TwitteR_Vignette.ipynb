# %%
# Author: Mitchel Taylor
#TwitteR Vignette

# %%
#http://geoffjentry.hexdump.org/twitteR.pdf

# %%
install.packages("twitteR", repos="http://cran.us.r-project.org/")
library(twitteR)
# Out:
# Installing package into 'C:/Users/Mitch/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# package 'twitteR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Mitch\AppData\Local\Temp\RtmpeijAaQ\downloaded_packages

# %%
#setup_twitter_oauth("API KEY","API SECRET","ACCESS TOKEN","ACCESS SECRET")
setup_twitter_oauth("",	"","","")
# Out:
# [1] "Using direct authentication"

# %%
#Getting User Data - Joe Rogan
tweets <- searchTwitter('#crimea',n=50);
head(tweets)

head(strip_retweets(tweets,strip_manual=TRUE,strip_mt=TRUE))
user_JoeRogan <-getUser('JoeRogan')
user_JoeRogan$getDescription()
user_JoeRogan$getFollowersCount()
user_JoeRogan$getFriends()
user_JoeRogan$getFavorites(n=5)
df <- twListToDF(tweets)
head(df)
# Out:
# [[1]]
# [1] "RevueLeBanquet: RT @O530CarrisPT: I agree. If the #Crimea cause fails, the territorial integrity will be undermined &amp; European order will be in risk. https"
#
# [[2]]
# [1] "RevueLeBanquet: RT @NTenzer: Good reason enough not to give in\n#sanctions on #Russia must remain over #Donbas AND #Crimea\nExplains too #Putin's meddling in"
#
# [[3]]
# [1] "Natteramnoslo: @JesusFromMars \nGrab more land \n\n#thirdreich #lebensraum #adolphputin #putout #StopPutin #genocide #crimea #Donetsk #Lugansk #MH17 #ICC"
#
# [[4]]
# [1] "Msarikamis: AYNENNI (Besik yiri)\nhttps://t.co/pCf3PinBh4\n#Kirim #kiriminsesi #tatar #qirimbizim #TuerkiyeKirimaSesVer #crimea https://t.co/yKn2tuwQ2R"
#
# [[5]]
# [1] "qiriminsesi: AYNENNI (Besik yiri)\nhttps://t.co/L5oHsQFk8T\n#Kirim #kiriminsesi #tatar #qirimbizim #TuerkiyeKirimaSesVer #crimea https://t.co/JZTGXwqcHX"
#
# [[6]]
# ...

# %%
#TimeLine
JoeRogan_tweets_Large <- userTimeline('JoeRogan',n=100)
length(JoeRogan_tweets_Large)
# Out:
# [1] 72

# %%
#Trends
available_trends = availableTrendLocations()
head(available_trends)
# Out:
#   name      country woeid
# 1 Worldwide         1
# 2 Winnipeg  Canada  2972
# 3 Ottawa    Canada  3369
# 4 Quebec    Canada  3444
# 5 Montreal  Canada  3534
# 6 Toronto   Canada  4118

# %%
#EXAMPLE - RSTATS
r_tweets <-searchTwitter("#rstats",n=300);
sources <- sapply(r_tweets,function(x) x$getStatusSource())
sources <- gsub("</a>","",sources)
sources <- strsplit(sources,">")
sources <- sapply(sources,function(x) ifelse(length(x) > 1, x[2],x[1]))
source_table = table(sources)
pie(source_table[source_table > 10])
# Out:
# plot without title
